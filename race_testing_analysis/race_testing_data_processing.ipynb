# 13                              NaN            NaN             NaN        0
# 14           05/04/2024 06:41:49 PM       Template             NaN        0
# 15           05/04/2024 06:48:08 PM       Template             NaN        0
# 0                               NaN            NaN             NaN        0
# 1            05/04/2024 11:02:28 PM       Template             NaN        0
# 2            05/04/2024 11:04:14 PM       Template             NaN        0
# 3            05/04/2024 11:04:39 PM       Template             NaN        0
# 4            05/04/2024 11:05:01 PM       Template             NaN        0
# 5                               NaN            NaN             NaN        0
# 6            05/04/2024 11:17:18 PM       Template             NaN        0
#
#     Bonus  Fees    Status                                          Task Data  \
# 0       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 1       0     0  Returned                                                NaN
# 2       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 3       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 4       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 5       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 0       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 1       0     0  Returned                                                NaN
# 2       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 3       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 4       0     0  Returned                                                NaN
# 5       0     0  Returned                                                NaN
# 6       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 7       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 0       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 1       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 2       0     0  Returned                                                NaN
# 3       0     0  Returned                                                NaN
# 4       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 5       0     0  Returned                                                NaN
# 6       0     0  Returned                                                NaN
# 7       0     0  Returned                                                NaN
# 8       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 9       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 0       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 1       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 2       0     0  Returned                                                NaN
# 3       0     0  Returned                                                NaN
# 4       0     0  Returned                                                NaN
# 5       0     0  Returned                                                NaN
# 6       0     0  Returned                                                NaN
# 7       0     0  Returned                                                NaN
# 8       0     0  Returned                                                NaN
# 9       0     0  Returned                                                NaN
# 10      0     0  Returned                                                NaN
# 11      0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 12      0     0  Returned                                                NaN
# 13      0     0  Returned                                                NaN
# 14      0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 15      0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 0       0     0  Returned                                                NaN
# 1       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 2       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 3       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 4       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
# 5       0     0  Returned                                                NaN
# 6       0     0   Pending  {"RowData":[{"CellData":"3.0","ColumnHeader":"...
#
#     ...                                          Education     Sex  \
# 0   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 1   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 2   ...                        Some college, but no degree    Male
# 3   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 4   ...                                No formal education    Male
# 5   ...                        Some college, but no degree  Female
# 0   ...        Bachelor's degree (for example: BA, AB, BS)    Male
# 1   ...                        Some college, but no degree    Male
# 2   ...  Master's degree (for example: MA, MS, MEng, ME...  Female
# 3   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 4   ...                        Some college, but no degree  Female
# 5   ...        Bachelor's degree (for example: BA, AB, BS)    Male
# 6   ...           Doctorate degree (for example: PhD, EdD)    Male
# 7   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 0   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 1   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 2   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 3   ...  Professional degree (for example: MD, DDS, DVM...    Male
# 4   ...             Associate degree (for example: AA, AS)    Male
# 5   ...  Master's degree (for example: MA, MS, MEng, ME...    Male
# 6   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 7   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 8   ...        Bachelor's degree (for example: BA, AB, BS)    Male
# 9   ...                        Some college, but no degree  Female
# 0   ...  High school graduate - high school diploma or ...    Male
# 1   ...        Bachelor's degree (for example: BA, AB, BS)    Male
# 2   ...             Associate degree (for example: AA, AS)  Female
# 3   ...                        Some college, but no degree  Female
# 4   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 5   ...                        Some college, but no degree  Female
# 6   ...                        Some college, but no degree  Female
# 7   ...  High school graduate - high school diploma or ...  Female
# 8   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 9   ...                        Some college, but no degree  Female
# 10  ...  High school graduate - high school diploma or ...  Female
# 11  ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 12  ...  Master's degree (for example: MA, MS, MEng, ME...  Female
# 13  ...  Master's degree (for example: MA, MS, MEng, ME...  Female
# 14  ...  Master's degree (for example: MA, MS, MEng, ME...  Female
# 15  ...           Doctorate degree (for example: PhD, EdD)  Female
# 0   ...             Associate degree (for example: AA, AS)    Male
# 1   ...             Associate degree (for example: AA, AS)  Female
# 2   ...  Master's degree (for example: MA, MS, MEng, ME...    Male
# 3   ...                        Some college, but no degree    Male
# 4   ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 5   ...  High school graduate - high school diploma or ...  Female
# 6   ...        Bachelor's degree (for example: BA, AB, BS)  Female
#
#                                   Occupation Field  \
# 0                              Marketing and Sales
# 1                           Information Technology
# 2                                  Social Sciences
# 3             Business Management & Administration
# 4                               I’d Rather Not Say
# 5                                            Other
# 0                           Information Technology
# 1                                            Other
# 2                                            Other
# 3                                  Social Sciences
# 4                                            Other
# 5                           Information Technology
# 6                                  Social Sciences
# 7                               I’d Rather Not Say
# 0                                            Legal
# 1                                          Retired
# 2                               I’d Rather Not Say
# 3                                         Medicine
# 4                                           Retail
# 5         Transportation, Distribution & Logistics
# 6                             Education & Training
# 7                                            Other
# 8   Science, Technology, Engineering & Mathematics
# 9                                           Retail
# 0                                    Manufacturing
# 1         Transportation, Distribution & Logistics
# 2                                         Medicine
# 3                                             Arts
# 4                                          Finance
# 5                                           Retail
# 6                                            Other
# 7                               I’d Rather Not Say
# 8                                  Social Sciences
# 9                                          Retired
# 10                                          Retail
# 11                            Education & Training
# 12                          Information Technology
# 13                                           Other
# 14                                 Social Sciences
# 15                            Education & Training
# 0                                             Arts
# 1                                          Retired
# 2                           Information Technology
# 3                           Information Technology
# 4   Science, Technology, Engineering & Mathematics
# 5         Transportation, Distribution & Logistics
# 6                                         Medicine
#
#    Relationship/Marital Status    Political Party Gender Country Of Residence  \
# 0                      Married         Republican  Woman        United States
# 1            In a relationship        Independent  Woman        United States
# 2                       Single           Democrat    Man        United States
# 3                      Married        Independent  Woman        United States
# 4                       Single     Something else    Man        United States
# 5            In a relationship           Democrat  Woman        United States
# 0                      Married         Republican    Man        United States
# 1                       Single           Democrat    Man        United States
# 2                       Single           Democrat  Woman        United States
# 3                      Married         Republican  Woman        United States
# 4                      Married  Prefer not to say  Woman        United States
# 5                      Married         Republican    Man        United States
# 6                       Single           Democrat    Man        United States
# 7                       Single           Democrat  Woman        United States
# 0                      Married           Democrat  Woman        United States
# 1                      Married        Independent  Woman        United States
# 2                       Single           Democrat  Woman        United States
# 3                      Married           Democrat    Man        United States
# 4                       Single        Independent    Man        United States
# 5                      Married        Independent    Man        United States
# 6                      Married           Democrat  Woman        United States
# 7                      Married           Democrat  Woman        United States
# 8                      Married           Democrat    Man        United States
# 9            In a relationship           Democrat  Woman        United States
# 0                       Single         Republican    Man        United States
# 1                       Single     Something else    Man        United States
# 2            In a relationship  Prefer not to say  Woman        United States
# 3                      Married           Democrat  Woman        United States
# 4                       Single           Democrat  Woman        United States
# 5                       Single           Democrat  Woman        United States
# 6            In a relationship         Republican  Woman        United States
# 7            In a relationship         Republican  Woman        United States
# 8                     Divorced         Republican  Woman        United States
# 9                      Married         Republican  Woman        United States
# 10                      Single           Democrat  Woman        United States
# 11                      Single        Independent  Woman        United States
# 12           In a relationship     Something else  Woman        United States
# 13                     Married         Republican  Woman        United States
# 14           In a relationship           Democrat  Woman        United States
# 15                     Married           Democrat  Woman        United States
# 0                       Single        Independent    Man        United States
# 1                       Single        Independent  Woman        United States
# 2                      Married  Prefer not to say    Man        United States
# 3                       Single           Democrat    Man        United States
# 4                      Married        Independent  Woman        United States
# 5            In a relationship        Independent  Woman        United States
# 6                      Married         Republican  Woman        United States
#
#       Household Income                          Race  \
# 0    $100,000-$124,999                         White
# 1     $250,000 or more                       Chinese
# 2    Less than $10,000                         White
# 3    $200,000-$224,999                         White
# 4      $30,000-$39,999                         White
# 5      $70,000-$79,999                         White
# 0    $100,000-$124,999                         White
# 1   $150,0000-$174,999                       Chinese
# 2      $10,000-$19,999     Black or African American
# 3      $40,000-$49,999                         White
# 4      $50,000-$59,999                         White
# 5      $90,000-$99,999     Black or African American
# 6    $100,000-$124,999                         White
# 7    Less than $10,000                         White
# 0    $125,000-$149,999                      Filipino
# 1   $150,0000-$174,999                         White
# 2      $30,000-$39,999                       Chinese
# 3     $250,000 or more                         White
# 4      $60,000-$69,999                         White
# 5    $200,000-$224,999                         White
# 6      $30,000-$39,999                         White
# 7    $100,000-$124,999                         White
# 8      $70,000-$79,999                       Chinese
# 9   $150,0000-$174,999                         White
# 0      $50,000-$59,999     Black or African American
# 1      $30,000-$39,999                         White
# 2      $60,000-$69,999  An ethnicity not listed here
# 3    $125,000-$149,999                         White
# 4      $40,000-$49,999                         White
# 5      $40,000-$49,999                         White
# 6      $40,000-$49,999                         White
# 7      $20,000-$29,999                         White
# 8      $70,000-$79,999                         White
# 9      $70,000-$79,999                         White
# 10     $50,000-$59,999                         White
# 11   Prefer not to say  An ethnicity not listed here
# 12     $40,000-$49,999                         White
# 13   $100,000-$124,999                         White
# 14     $50,000-$59,999                         White
# 15   $175,000-$199,999                         White
# 0    Less than $10,000                    Vietnamese
# 1      $10,000-$19,999                         White
# 2   $150,0000-$174,999                         Other
# 3      $30,000-$39,999     Black or African American
# 4     $250,000 or more                    Vietnamese
# 5      $20,000-$29,999                         White
# 6   $150,0000-$174,999                         White
#
#                                Employment Status
# 0                                      Part-time
# 1                                      Full-time
# 2                                        Student
# 3                                      Full-time
# 4   Not in paid work (e.g., homemaker, disabled)
# 5                                        Student
# 0                                      Full-time
# 1                                        Student
# 2                                     Unemployed
# 3                                      Full-time
# 4                              Prefer not to say
# 5                                      Full-time
# 6                                      Full-time
# 7                                     Unemployed
# 0                                      Part-time
# 1                                        Retired
# 2                                        Student
# 3                                      Full-time
# 4                                 Business Owner
# 5                                      Full-time
# 6                                      Full-time
# 7                                     Unemployed
# 8                                      Full-time
# 9                                      Full-time
# 0                                      Full-time
# 1                                      Full-time
# 2                                      Full-time
# 3                                 Business Owner
# 4                                      Part-time
# 5   Not in paid work (e.g., homemaker, disabled)
# 6                                      Full-time
# 7                                     Unemployed
# 8                                      Full-time
# 9                                        Retired
# 10                                     Full-time
# 11                                       Student
# 12                                     Part-time
# 13  Not in paid work (e.g., homemaker, disabled)
# 14                                     Part-time
# 15                                     Full-time
# 0                                        Student
# 1   Not in paid work (e.g., homemaker, disabled)
# 2                                      Full-time
# 3                                     Unemployed
# 4                                      Full-time
# 5                                      Part-time
# 6                                      Full-time
#
# [47 rows x 22 columns]

# %% [markdown]
# ### cleaning and formatting df

# %%
respondent_df.columns
# Out:
# Index(['ParticipantId', 'StartTime (America/Chicago)',
#        'CompletionTime (America/Chicago)', 'CompletionType', 'CompletionCode',
#        'Payment', 'Bonus', 'Fees', 'Status', 'Task Data', 'Submitted Data',
#        'Age', 'Education', 'Sex', 'Occupation Field',
#        'Relationship/Marital Status', 'Political Party', 'Gender',
#        'Country Of Residence', 'Household Income', 'Race',
#        'Employment Status'],
#       dtype='object')

# %%
# want only actual responses (responses that are "Pending")

respondent_df = respondent_df[respondent_df["Status"] == "Pending"]

# %%
relevant_columns = ['ParticipantId', 'Task Data', 'Submitted Data',
       'Age', 'Education', 'Sex', 'Occupation Field',
       'Relationship/Marital Status', 'Political Party', 'Gender',
       'Country Of Residence', 'Household Income', 'Race',
       'Employment Status']

respondent_df = respondent_df[relevant_columns]
respondent_df = respondent_df.reset_index(drop = True)

# %%
respondent_demographics_df = respondent_df.drop(columns = ["Task Data", "Submitted Data"])

# %%
respondent_data_df = respondent_df[["Task Data", "Submitted Data"]]

# %%
respondent_data_df["Submitted Data"][0]
# Out:
# '{"Data":{"taskData":{"age":"50\\u0027s","jaw":"triangle shaped, not strongly defined ","eyes":"almond shaped, brown ","hair":"straight gray","nose":"long and pointy, large nostrils","race":"white","beard":"no","gender":"male","eyebrows":"slightly bushy gray","expression":"smiling","additionalInfo":"Slight "}}}'

# %%
def get_data_from_json(task_json: str, task: bool):
    """
    Returns the value associated with the given field attribute (ex: Race, Memorable)
    Args:
        field: the specific field that is being retrieved from the JSON 
        task: Boolean True if it is task data, False if it is respondent data (accessing JSON differs)
    """
    json_object = json.loads(task_json)
    if task: 
        json_object_rows = json_object["RowData"]
        task_columns = [row["ColumnHeader"] for row in json_object_rows]
        task_columns = [column + "_og_img" for column in task_columns]
        json_object_row_headers_values = [row["CellData"] for row in json_object_rows]
        res_dict = {task_columns[i]: json_object_row_headers_values[i] for i in range(len(task_columns))}
        return res_dict
    else:
        json_object_rows = json_object["Data"]
        description_data = json_object_rows["taskData"]
        description_headers = ([*description_data.keys()])
        description_headers = [column + "_description" for column in description_headers]
        description_values = ([*description_data.values()])
        res_dict = {description_headers[i]: description_values[i] for i in range(len(description_values))}
        return res_dict

# %%
def reconstruct_output_df(respondent_df):
    """
    Returns the value associated with the given field attribute (ex: Race, Memorable)
    Args:
        field: the specific field that is being retrieved from the JSON 
        task: Boolean True if it is task data, False if it is respondent data (accessing JSON differs)
    """
    
    # creating the new columns for each row of the task data
    expanded_task_data = respondent_df.apply(lambda row: get_data_from_json(row["Task Data"], task = True), axis = 1, result_type = 'expand')
    respondent_df = pd.concat([expanded_task_data, respondent_df], axis = "columns")

    # getting the columns associated with one respondent description (same for all respondents so generalizable to other rows)
    expanded_description_data = respondent_df.apply(lambda row: get_data_from_json(row["Submitted Data"], task = False), axis = 1, result_type = 'expand')
    respondent_df = pd.concat([expanded_description_data, respondent_df], axis = "columns")
    
    return respondent_df

# %%
race_testing_df = reconstruct_output_df(respondent_df)

# %%
race_testing_df.to_csv("race_testing_output.csv", mode="w", index=False)

# %%
race_testing_df
# Out:
#    age_description                         jaw_description  \
# 0             50's  triangle shaped, not strongly defined
# 1          mid 40s                                    Wide
# 2               32                                  normal
# 3          mid-40s                               round jaw
# 4          Mid 40s                                    Oval
# 5          mid-50s                                  Square
# 6         mid-20's                                 rounded
# 7          Mid 30s                                 Rounded
# 8          mid-50s                          Medium, square
# 9               40                                     N/A
# 10       late 40's                                squarish
# 11             50s                                 rounded
# 12         Mid 40s                                Rounded
# 13       early 30s                          slightly round
# 14        Late 30s                                   Round
# 15         mid 40s                           short pointed
# 16             50s                                 rounded
# 17         mid 30s                                oval jaw
# 18             40s                                  round
# 19       early 40s         squishy jaw with a pointed chin
# 20        Late 40s                            Unremarkable
# 21              55                                    oval
# 22        late 20s                               round jaw
# 23        Late 30s                                  Square
# 24              32                                  Round
#
#                eyes_description  \
# 0         almond shaped, brown
# 1                      Big nose
# 2                 dark, slanted
# 3                         brown
# 4       Small and hazel, hooded
# 5                   Small brown
# 6              small brown eyes
# 7                   Large black
# 8                   Large brown
# 9                 White average
# 10               squinted brown
# 11                 large, brown
# 12                 Small brown
# 13                   dark brown
# 14              Small and brown
# 15            small light brown
# 16                        brown
# 17                  large brown
# 18               average brown
# 19  brown, not especially large
# 20                  Small brown
# 21                  large black
# 22        medium size and brown
# 23                 Large black
# 24                      Medium
#
#                                   hair_description  \
# 0                                    straight gray
# 1                               Big brown eyebrows
# 2                           appears to be straight
# 3                                   thinning black
# 4   Pulled back, tightly coiled, curly, dark brown
# 5                             Short straight brown
# 6                              straight black hair
# 7                                            Short
# 8                                             bald
# 9                                       Wavy brown
# 10                 moderate straight graying brown
# 11             short, tight, curly black with gray
# 12                                 Short and brown
# 13                             long straight black
# 14                             Long curly brunette
# 15              short brown hair with some graying
# 16                                         graying
# 17                                     thin coarse
# 18             brown, frizzy, in a bun or ponytail
# 19               Short brown hair, thinning on top
# 20                                    Short blonde
# 21                                           black
# 22                                      long brown
# 23                                 Short thin hair
# 24                           Light brown straight
#
#                             nose_description            race_description  \
# 0            long and pointy, large nostrils                       white
# 1                                  Wide and                        black
# 2                                       wide                       asian
# 3                                pointy nose  middle_eastern_south_asian
# 4   Short bridge, flared nostrils, flat base                    hispanic
# 5                           Long and rounded                       white
# 6                               small stouty                       asian
# 7                        Flat large nostrils  middle_eastern_south_asian
# 8                Large nose, flared nostrils                       black
# 9                                    Average                       white
# 10                                 straight                        white
# 11                          wide and rounded                       black
# 12           Wide nostril and a long bridge                        asian
# 13                                    normal                       asian
# 14               Small nostrils not pointed                     hispanic
# 15                         long pointed nose                       white
# 16                                     large                       black
# 17                            small nostrils                       asian
# 18                                      wide                    hispanic
# 19     straight long nose with a wide bottom  middle_eastern_south_asian
# 20                                      Thin                       white
# 21                 slightly wide and pointed                       black
# 22      smallish nostrils, normal sized nose                       asian
# 23                                Large nose                       asian
# 24                             small narrow                     hispanic
#
#                                     beard_description gender_description  \
# 0                                                  no               male
# 1                                         Non visible               male
# 2                                                none             female
# 3                                                none               male
# 4                                                None             female
# 5                                                None               male
# 6                                                None             female
# 7                                            No beard               male
# 8                  Medium moustache, small chin patch               male
# 9                                             Smiling             female
# 10                                               none               male
# 11                                               none               male
# 12                                               None               male
# 13                                               none             female
# 14                                               None             female
# 15                                               None               male
# 16                                               none               male
# 17                                               none             female
# 18                                               none             female
# 19  no beard but pronounced stuble on his chin and...               male
# 20                                               None               male
# 21                                               none               male
# 22                                                NaN             female
# 23                                           No beard               male
# 24                                              None              female
#
#                    eyebrows_description expression_description  ...  \
# 0                   slightly bushy gray                smiling  ...
# 1                 Brown but looks black                smiling  ...
# 2                                  thin                smiling  ...
# 3                                blaack                smiling  ...
# 4            Thin dark brown and arched                smiling  ...
# 5                           Thick brown                smiling  ...
# 6                slightly thin eyebrows                smiling  ...
# 7                           Thick black                smiling  ...
# 8          Medium, grey/white and black                smiling  ...
# 9                                Brown                 smiling  ...
# 10                       moderate brown                smiling  ...
# 11                         thick ,dark                 smiling  ...
# 12                      Thick and small                smiling  ...
# 13                          thick black                smiling  ...
# 14                          Thick brown                smiling  ...
# 15                           thin brown                smiling  ...
# 16                                 dark                smiling  ...
# 17                                brown                smiling  ...
# 18                         medium brown                smiling  ...
# 19  normal width brown, slightly sparse                smiling  ...
# 20                          Thin blonde                smiling  ...
# 21                                black                  other  ...
# 22              thin same color as hair                smiling  ...
# 23                    Short thick brown                smiling  ...
# 24                                 Thin                smiling  ...
#
#                                             Education     Sex  \
# 0         Bachelor's degree (for example: BA, AB, BS)  Female
# 1                         Some college, but no degree    Male
# 2         Bachelor's degree (for example: BA, AB, BS)  Female
# 3                                 No formal education    Male
# 4                         Some college, but no degree  Female
# 5         Bachelor's degree (for example: BA, AB, BS)    Male
# 6   Master's degree (for example: MA, MS, MEng, ME...  Female
# 7         Bachelor's degree (for example: BA, AB, BS)  Female
# 8            Doctorate degree (for example: PhD, EdD)    Male
# 9         Bachelor's degree (for example: BA, AB, BS)  Female
# 10        Bachelor's degree (for example: BA, AB, BS)  Female
# 11        Bachelor's degree (for example: BA, AB, BS)  Female
# 12             Associate degree (for example: AA, AS)    Male
# 13        Bachelor's degree (for example: BA, AB, BS)    Male
# 14                        Some college, but no degree  Female
# 15  High school graduate - high school diploma or ...    Male
# 16        Bachelor's degree (for example: BA, AB, BS)    Male
# 17        Bachelor's degree (for example: BA, AB, BS)  Female
# 18  Master's degree (for example: MA, MS, MEng, ME...  Female
# 19           Doctorate degree (for example: PhD, EdD)  Female
# 20             Associate degree (for example: AA, AS)  Female
# 21  Master's degree (for example: MA, MS, MEng, ME...    Male
# 22                        Some college, but no degree    Male
# 23        Bachelor's degree (for example: BA, AB, BS)  Female
# 24        Bachelor's degree (for example: BA, AB, BS)  Female
#
#                                   Occupation Field  \
# 0                              Marketing and Sales
# 1                                  Social Sciences
# 2             Business Management & Administration
# 3                               I’d Rather Not Say
# 4                                            Other
# 5                           Information Technology
# 6                                            Other
# 7                                  Social Sciences
# 8                                  Social Sciences
# 9                               I’d Rather Not Say
# 10                                           Legal
# 11                                         Retired
# 12                                          Retail
# 13  Science, Technology, Engineering & Mathematics
# 14                                          Retail
# 15                                   Manufacturing
# 16        Transportation, Distribution & Logistics
# 17                            Education & Training
# 18                                 Social Sciences
# 19                            Education & Training
# 20                                         Retired
# 21                          Information Technology
# 22                          Information Technology
# 23  Science, Technology, Engineering & Mathematics
# 24                                        Medicine
#
#    Relationship/Marital Status    Political Party Gender Country Of Residence  \
# 0                      Married         Republican  Woman        United States
# 1                       Single           Democrat    Man        United States
# 2                      Married        Independent  Woman        United States
# 3                       Single     Something else    Man        United States
# 4            In a relationship           Democrat  Woman        United States
# 5                      Married         Republican    Man        United States
# 6                       Single           Democrat  Woman        United States
# 7                      Married         Republican  Woman        United States
# 8                       Single           Democrat    Man        United States
# 9                       Single           Democrat  Woman        United States
# 10                     Married           Democrat  Woman        United States
# 11                     Married        Independent  Woman        United States
# 12                      Single        Independent    Man        United States
# 13                     Married           Democrat    Man        United States
# 14           In a relationship           Democrat  Woman        United States
# 15                      Single         Republican    Man        United States
# 16                      Single     Something else    Man        United States
# 17                      Single        Independent  Woman        United States
# 18           In a relationship           Democrat  Woman        United States
# 19                     Married           Democrat  Woman        United States
# 20                      Single        Independent  Woman        United States
# 21                     Married  Prefer not to say    Man        United States
# 22                      Single           Democrat    Man        United States
# 23                     Married        Independent  Woman        United States
# 24                     Married         Republican  Woman        United States
#
#       Household Income                          Race  \
# 0    $100,000-$124,999                         White
# 1    Less than $10,000                         White
# 2    $200,000-$224,999                         White
# 3      $30,000-$39,999                         White
# 4      $70,000-$79,999                         White
# 5    $100,000-$124,999                         White
# 6      $10,000-$19,999     Black or African American
# 7      $40,000-$49,999                         White
# 8    $100,000-$124,999                         White
# 9    Less than $10,000                         White
# 10   $125,000-$149,999                      Filipino
# 11  $150,0000-$174,999                         White
# 12     $60,000-$69,999                         White
# 13     $70,000-$79,999                       Chinese
# 14  $150,0000-$174,999                         White
# 15     $50,000-$59,999     Black or African American
# 16     $30,000-$39,999                         White
# 17   Prefer not to say  An ethnicity not listed here
# 18     $50,000-$59,999                         White
# 19   $175,000-$199,999                         White
# 20     $10,000-$19,999                         White
# 21  $150,0000-$174,999                         Other
# 22     $30,000-$39,999     Black or African American
# 23    $250,000 or more                    Vietnamese
# 24  $150,0000-$174,999                         White
#
#                                Employment Status
# 0                                      Part-time
# 1                                        Student
# 2                                      Full-time
# 3   Not in paid work (e.g., homemaker, disabled)
# 4                                        Student
# 5                                      Full-time
# 6                                     Unemployed
# 7                                      Full-time
# 8                                      Full-time
# 9                                     Unemployed
# 10                                     Part-time
# 11                                       Retired
# 12                                Business Owner
# 13                                     Full-time
# 14                                     Full-time
# 15                                     Full-time
# 16                                     Full-time
# 17                                       Student
# 18                                     Part-time
# 19                                     Full-time
# 20  Not in paid work (e.g., homemaker, disabled)
# 21                                     Full-time
# 22                                    Unemployed
# 23                                     Full-time
# 24                                     Full-time
#
# [25 rows x 30 columns]
