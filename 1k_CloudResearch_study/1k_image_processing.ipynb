# %% [markdown]
# # Processing the 1k Image dataset for DALL-E & CNN

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### combining the CloudResearch datasets into one DF

# %%
respondent_df = pd.read_csv("1k_dataset_1.csv")

for i in np.arange(1, 2):
    csv = "1k_dataset_" + str(i) + ".csv"
    csv_df = pd.read_csv(csv)
    respondent_df = pd.concat([respondent_df, csv_df])

respondent_df
# Out:
#                          ParticipantId StartTime (America/Chicago)  \
# 0     21C99EDBFCD34AA1B3538677865FA3C4      05/06/2024 06:34:40 PM
# 1     AB4D929E25A942249E8D34299746B1A6      05/06/2024 06:34:40 PM
# 2     3CA5DB2C4DAC403EA4D1A0AC45D33054      05/06/2024 06:34:51 PM
# 3     259269483C7F499FB657D6B8BD0C1C97      05/06/2024 06:34:53 PM
# 4     5E46EF4B2865489D9A79F709596A315F      05/06/2024 06:34:54 PM
# ...                                ...                         ...
# 1349  48CF0836208947F3A9C1303E7ED49A0A      05/06/2024 06:34:13 PM
# 1350  61DC9B9B1D064196A5DF2B7F6F6ADC80      05/06/2024 06:34:25 PM
# 1351  FCC8D9FC3CAD44BC9AA129B5A96241D4      05/06/2024 06:34:28 PM
# 1352  128BAFEE1C27463DACD32EBFB0AA0F80      05/06/2024 06:34:29 PM
# 1353  732DA4FE7BC640B19351B870E73F6C5C      05/06/2024 06:34:35 PM
#
#      CompletionTime (America/Chicago) CompletionType  CompletionCode  Payment  \
# 0                                 NaN            NaN             NaN        0
# 1                                 NaN            NaN             NaN        0
# 2                                 NaN            NaN             NaN        0
# 3              05/06/2024 06:36:48 PM       Template             NaN        0
# 4              05/06/2024 06:42:59 PM       Template             NaN        0
# ...                               ...            ...             ...      ...
# 1349           05/06/2024 06:38:03 PM       Template             NaN        0
# 1350                              NaN            NaN             NaN        0
# 1351                              NaN            NaN             NaN        0
# 1352           05/06/2024 06:37:19 PM       Template             NaN        0
# 1353           05/06/2024 06:42:54 PM       Template             NaN        0
#
#       Bonus  Fees    Status  \
# 0         0     0  Returned
# 1         0     0  Returned
# 2         0     0  Returned
# 3         0     0   Pending
# 4         0     0   Pending
# ...     ...   ...       ...
# 1349      0     0   Pending
# 1350      0     0  Returned
# 1351      0     0  Returned
# 1352      0     0   Pending
# 1353      0     0   Pending
#
#                                               Task Data  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3     {"RowData":[{"CellData":"4.0","ColumnHeader":"...  ...
# 4     {"RowData":[{"CellData":"4.0","ColumnHeader":"...  ...
# ...                                                 ...  ...
# 1349  {"RowData":[{"CellData":"5.0","ColumnHeader":"...  ...
# 1350                                                NaN  ...
# 1351                                                NaN  ...
# 1352  {"RowData":[{"CellData":"1.0","ColumnHeader":"...  ...
# 1353  {"RowData":[{"CellData":"3.0","ColumnHeader":"...  ...
#
#                                               Education     Sex  \
# 0                           Some college, but no degree  Female
# 1           Bachelor's degree (for example: BA, AB, BS)    Male
# 2           Bachelor's degree (for example: BA, AB, BS)    Male
# 3                           Some college, but no degree    Male
# 4     Master's degree (for example: MA, MS, MEng, ME...  Female
# ...                                                 ...     ...
# 1349             Associate degree (for example: AA, AS)  Female
# 1350  Master's degree (for example: MA, MS, MEng, ME...  Female
# 1351                        Some college, but no degree  Female
# 1352        Bachelor's degree (for example: BA, AB, BS)  Female
# 1353  Master's degree (for example: MA, MS, MEng, ME...  Female
#
#                           Occupation Field Relationship/Marital Status  \
# 0     Business Management & Administration           In a relationship
# 1                                     Arts           In a relationship
# 2                   Information Technology                     Married
# 3                                    Other                    Divorced
# 4                     Education & Training                     Married
# ...                                    ...                         ...
# 1349                              Medicine                     Widowed
# 1350                                  Arts                      Single
# 1351                Information Technology                      Single
# 1352                                  Arts                     Married
# 1353                               Finance                     Married
#
#      Political Party Gender Country Of Residence   Household Income  \
# 0           Democrat  Woman        United States  Prefer not to say
# 1           Democrat    Man        United States    $60,000-$69,999
# 2           Democrat    Man        United States  $200,000-$224,999
# 3           Democrat    Man        United States    $30,000-$39,999
# 4        Independent  Woman        United States  $100,000-$124,999
# ...              ...    ...                  ...                ...
# 1349     Independent  Woman        United States    $50,000-$59,999
# 1350        Democrat  Woman        United States  Less than $10,000
# 1351        Democrat  Woman        United States    $30,000-$39,999
# 1352        Democrat  Woman        United States   $250,000 or more
# 1353        Democrat  Woman        United States  $200,000-$224,999
#
#                               Race Employment Status
# 0                Prefer not to say        Unemployed
# 1     An ethnicity not listed here         Full-time
# 2                            White         Full-time
# 3                            White         Full-time
# 4                            White         Full-time
# ...                            ...               ...
# 1349     Black or African American         Full-time
# 1350                         White        Unemployed
# 1351     Black or African American         Full-time
# 1352                         White         Full-time
# 1353                         White         Full-time
#
# [2708 rows x 22 columns]

# %% [markdown]
# ### cleaning and formatting df

# %%
respondent_df.columns
# Out:
# Index(['ParticipantId', 'StartTime (America/Chicago)',
#        'CompletionTime (America/Chicago)', 'CompletionType', 'CompletionCode',
#        'Payment', 'Bonus', 'Fees', 'Status', 'Task Data', 'Submitted Data',
#        'Age', 'Education', 'Sex', 'Occupation Field',
#        'Relationship/Marital Status', 'Political Party', 'Gender',
#        'Country Of Residence', 'Household Income', 'Race',
#        'Employment Status'],
#       dtype='object')

# %%
# want only actual responses (responses that are "Pending")

respondent_df = respondent_df[respondent_df["Status"] == "Pending"]

# %%
relevant_columns = ['ParticipantId', 'Task Data', 'Submitted Data',
       'Age', 'Education', 'Sex', 'Occupation Field',
       'Relationship/Marital Status', 'Political Party', 'Gender',
       'Country Of Residence', 'Household Income', 'Race',
       'Employment Status']

respondent_df = respondent_df[relevant_columns]
respondent_df = respondent_df.reset_index(drop = True)

# %%
respondent_demographics_df = respondent_df.drop(columns = ["Task Data", "Submitted Data"])

# %%
respondent_data_df = respondent_df[["Task Data", "Submitted Data"]]

# %%
respondent_data_df["Submitted Data"][0]
# Out:
# '{"Data":{"taskData":{"age":"40s","jaw":"Rounded","eyes":"Hazel","hair":"Brown short","nose":"Smaller sharp","race":"white","beard":"None","gender":"female","eyebrows":"Brown","expression":"smiling"}}}'

# %%
def get_data_from_json(task_json: str, task: bool):
    """
    Returns the value associated with the given field attribute (ex: Race, Memorable)
    Args:
        field: the specific field that is being retrieved from the JSON 
        task: Boolean True if it is task data, False if it is respondent data (accessing JSON differs)
    """
    json_object = json.loads(task_json)
    if task: 
        json_object_rows = json_object["RowData"]
        task_columns = [row["ColumnHeader"] for row in json_object_rows]
        task_columns = [column + "_og_img" for column in task_columns]
        json_object_row_headers_values = [row["CellData"] for row in json_object_rows]
        res_dict = {task_columns[i]: json_object_row_headers_values[i] for i in range(len(task_columns))}
        return res_dict
    else:
        json_object_rows = json_object["Data"]
        description_data = json_object_rows["taskData"]
        description_headers = ([*description_data.keys()])
        description_headers = [column + "_description" for column in description_headers]
        description_values = ([*description_data.values()])
        res_dict = {description_headers[i]: description_values[i] for i in range(len(description_values))}
        return res_dict

# %%
def reconstruct_output_df(respondent_df):
    """
    Returns the value associated with the given field attribute (ex: Race, Memorable)
    Args:
        field: the specific field that is being retrieved from the JSON 
        task: Boolean True if it is task data, False if it is respondent data (accessing JSON differs)
    """
    
    # creating the new columns for each row of the task data
    expanded_task_data = respondent_df.apply(lambda row: get_data_from_json(row["Task Data"], task = True), axis = 1, result_type = 'expand')
    respondent_df = pd.concat([expanded_task_data, respondent_df], axis = "columns")

    # getting the columns associated with one respondent description (same for all respondents so generalizable to other rows)
    expanded_description_data = respondent_df.apply(lambda row: get_data_from_json(row["Submitted Data"], task = False), axis = 1, result_type = 'expand')
    respondent_df = pd.concat([expanded_description_data, respondent_df], axis = "columns")
    
    return respondent_df

# %%
race_testing_df = reconstruct_output_df(respondent_df)

# %%
race_testing_df.to_csv("1k_dataset_output.csv", mode="w", index=False)

# %%
race_testing_df
# Out:
#        age_description jaw_description  \
# 0                  40s         Rounded
# 1              mid 30s   pointed, soft
# 2                 90's     a round jaw
# 3                   42        Roundish
# 4                   37            Wide
# ...                ...             ...
# 1649  40s to early 50s    Rounded jaw
# 1650               50s           Round
# 1651             28-32  round jaw line
# 1652            Mid40s           Round
# 1653           Mid 40s          Cleft
#
#                                        eyes_description  \
# 0                                                 Hazel
# 1                                small, brown, friendly
# 2                                       light blue eyes
# 3                                                 Hazel
# 4                                                 Brown
# ...                                                 ...
# 1649                                               Dark
# 1650                                   small green eyes
# 1651  blue eyes left eye shaped differently than rig...
# 1652                                 Medium sized brown
# 1653  Blue, left larger than right, crows feet at ou...
#
#                           hair_description  \
# 0                              Brown short
# 1                   short, brown, straight
# 2                       short cropped hair
# 3                                     Gray
# 4                                    Brown
# ...                                    ...
# 1649                        Brown or black
# 1650         Short-thin, receding hairline
# 1651          Blonde with brown highlights
# 1652  Pulled back dark brown straight hair
# 1653                Short, brown, receding
#
#                             nose_description race_description  \
# 0                              Smaller sharp            white
# 1                       wide, small nostrils            white
# 2                                  wide nose            black
# 3                                    Average            white
# 4                                     Narrow            white
# ...                                      ...              ...
# 1649                  Medium sized nostrils             asian
# 1650               Small nostrils big bridge            white
# 1651                  long bridge sharp tip             white
# 1652                 Medium, larger nostrils            other
# 1653  Average size, blemish between eyebrows            white
#
#                          beard_description gender_description  \
# 0                                     None             female
# 1                  brown, scruffy, mustash               male
# 2                                 no beard             female
# 3                              Slight gray               male
# 4                                   Shaved               male
# ...                                    ...                ...
# 1649                       No facial hair              female
# 1650  Thick bushy mustache with beard trim               male
# 1651                                  none             female
# 1652                                  None             female
# 1653                         Razor stubble               male
#
#                                eyebrows_description expression_description  \
# 0                                             Brown                smiling
# 1                                     brown, whispy                smiling
# 2                              thinning light brows                smiling
# 3                                              Gray                neutral
# 4                                            Narrow                smiling
# ...                                             ...                    ...
# 1649                                    Thick black                smiling
# 1650                            Thin darkish blonde                smiling
# 1651                         arched bark brown thin                smiling
# 1652                     Thin brown not very large                 neutral
# 1653  Thick, dark, right appears to be half missing                smiling
#
#       ...                                          Education     Sex  \
# 0     ...                        Some college, but no degree    Male
# 1     ...  Master's degree (for example: MA, MS, MEng, ME...  Female
# 2     ...  High school graduate - high school diploma or ...  Female
# 3     ...  High school graduate - high school diploma or ...    Male
# 4     ...        Bachelor's degree (for example: BA, AB, BS)    Male
# ...   ...                                                ...     ...
# 1649  ...  Master's degree (for example: MA, MS, MEng, ME...    Male
# 1650  ...  High school graduate - high school diploma or ...    Male
# 1651  ...             Associate degree (for example: AA, AS)  Female
# 1652  ...        Bachelor's degree (for example: BA, AB, BS)  Female
# 1653  ...  Master's degree (for example: MA, MS, MEng, ME...  Female
#
#           Occupation Field Relationship/Marital Status    Political Party  \
# 0                    Other                    Divorced           Democrat
# 1     Education & Training                     Married        Independent
# 2                   Retail           In a relationship  Prefer not to say
# 3                    Other                      Single           Democrat
# 4                   Retail                      Single     Something else
# ...                    ...                         ...                ...
# 1649  Education & Training                     Married           Democrat
# 1650                 Other                     Married           Democrat
# 1651              Medicine                     Widowed        Independent
# 1652                  Arts                     Married           Democrat
# 1653               Finance                     Married           Democrat
#
#      Gender Country Of Residence   Household Income  \
# 0       Man        United States    $30,000-$39,999
# 1     Woman        United States  $100,000-$124,999
# 2     Woman        United States  Prefer not to say
# 3       Man        United States    $20,000-$29,999
# 4       Man        United States    $10,000-$19,999
# ...     ...                  ...                ...
# 1649    Man        United States  $100,000-$124,999
# 1650    Man        United States    $70,000-$79,999
# 1651  Woman        United States    $50,000-$59,999
# 1652  Woman        United States   $250,000 or more
# 1653  Woman        United States  $200,000-$224,999
#
#                            Race  Employment Status
# 0                         White          Full-time
# 1                         White          Full-time
# 2                         White          Full-time
# 3     Black or African American            Student
# 4                         White            Student
# ...                         ...                ...
# 1649                      White          Full-time
# 1650                   Filipino          Full-time
# 1651  Black or African American          Full-time
# 1652                      White          Full-time
# 1653                      White          Full-time
#
# [1654 rows x 30 columns]

# %%
files_to_drop = race_testing_df["Filename_og_img"].values
files_to_drop
# Out:
# array(['Google_1_Jane Standifer_11_oval.jpg',
#        'Google_1_Louis Sung_1_oval.jpg',
#        'Google_1_Lorraine Byrd_9_oval.jpg', ...,
#        'Google_1_Chad Brister_11_oval.jpg',
#        'Google_1_Tamara Pharr_9_oval.jpg',
#        'Google_1_Eric Croft_1_oval.jpg'], dtype=object)

# %%
images_1k_df = pd.read_csv("1k-images.csv").
images_1k_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wz/7k6v05bx5gvffw4vkwfkmkn40000gn/T/ipykernel_89378/3693420815.py in <module>
# ----> 1 images_1k_df = pd.read_csv("1k-images.csv").values()
#       2 images_1k_df
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
# dropping these images from the 1k dataset for new survey 
images_1k_df = pd.read_csv("1k-images.csv")
second_survey_df = images_1k_df[~images_1k_df["Filename"].isin(files_to_drop)]

# %%
second_survey_df
# Out:
#      Attractive  Race  Memorable                                   Filename  \
# 592         3.0   1.0        3.0       Google_1_Sean Bissonnette_1_oval.jpg
# 677         2.0   1.0        2.0        Google_1_Larry Perryman_13_oval.jpg
# 726         3.0   1.0        4.0       Google_1_Samuel Chartier_17_oval.jpg
# 748         2.0   1.0        2.0          Google_1_Jack Province_9_oval.jpg
# 758         3.0   1.0        3.0          Google_1_Wayne Barrios_9_oval.jpg
# ..          ...   ...        ...                                        ...
# 995         1.0   2.0        1.0          Google_1_Gregory Given_1_oval.jpg
# 996         3.0   1.0        3.0           Google_1_Mike Spruill_3_oval.jpg
# 997         2.0   2.0        4.0  Google_1_Danielle Christenson_15_oval.jpg
# 998         2.0   1.0        3.0       Google_1_Catherine Fiske_17_oval.jpg
# 999         3.0   1.0        3.0          Google_1_Diana Bateman_7_oval.jpg
#
#                                                AWSFile
# 592  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 677  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 726  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 748  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 758  https://mturk-1k-images.s3.amazonaws.com/Googl...
# ..                                                 ...
# 995  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 996  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 997  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 998  https://mturk-1k-images.s3.amazonaws.com/Googl...
# 999  https://mturk-1k-images.s3.amazonaws.com/Googl...
#
# [173 rows x 5 columns]

# %%
second_survey_df.to_csv("1k_survey_2.csv", mode="w", index=False)

# %%
# getting the list of participants who have taken the survey already 
first_survey = pd.read_csv("1k_dataset_1.csv")
first_survey
# Out:
#                          ParticipantId StartTime (America/Chicago)  \
# 0     21C99EDBFCD34AA1B3538677865FA3C4      05/06/2024 06:34:40 PM
# 1     AB4D929E25A942249E8D34299746B1A6      05/06/2024 06:34:40 PM
# 2     3CA5DB2C4DAC403EA4D1A0AC45D33054      05/06/2024 06:34:51 PM
# 3     259269483C7F499FB657D6B8BD0C1C97      05/06/2024 06:34:53 PM
# 4     5E46EF4B2865489D9A79F709596A315F      05/06/2024 06:34:54 PM
# ...                                ...                         ...
# 1349  48CF0836208947F3A9C1303E7ED49A0A      05/06/2024 06:34:13 PM
# 1350  61DC9B9B1D064196A5DF2B7F6F6ADC80      05/06/2024 06:34:25 PM
# 1351  FCC8D9FC3CAD44BC9AA129B5A96241D4      05/06/2024 06:34:28 PM
# 1352  128BAFEE1C27463DACD32EBFB0AA0F80      05/06/2024 06:34:29 PM
# 1353  732DA4FE7BC640B19351B870E73F6C5C      05/06/2024 06:34:35 PM
#
#      CompletionTime (America/Chicago) CompletionType  CompletionCode  Payment  \
# 0                                 NaN            NaN             NaN        0
# 1                                 NaN            NaN             NaN        0
# 2                                 NaN            NaN             NaN        0
# 3              05/06/2024 06:36:48 PM       Template             NaN        0
# 4              05/06/2024 06:42:59 PM       Template             NaN        0
# ...                               ...            ...             ...      ...
# 1349           05/06/2024 06:38:03 PM       Template             NaN        0
# 1350                              NaN            NaN             NaN        0
# 1351                              NaN            NaN             NaN        0
# 1352           05/06/2024 06:37:19 PM       Template             NaN        0
# 1353           05/06/2024 06:42:54 PM       Template             NaN        0
#
#       Bonus  Fees    Status  \
# 0         0     0  Returned
# 1         0     0  Returned
# 2         0     0  Returned
# 3         0     0   Pending
# 4         0     0   Pending
# ...     ...   ...       ...
# 1349      0     0   Pending
# 1350      0     0  Returned
# 1351      0     0  Returned
# 1352      0     0   Pending
# 1353      0     0   Pending
#
#                                               Task Data  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3     {"RowData":[{"CellData":"4.0","ColumnHeader":"...  ...
# 4     {"RowData":[{"CellData":"4.0","ColumnHeader":"...  ...
# ...                                                 ...  ...
# 1349  {"RowData":[{"CellData":"5.0","ColumnHeader":"...  ...
# 1350                                                NaN  ...
# 1351                                                NaN  ...
# 1352  {"RowData":[{"CellData":"1.0","ColumnHeader":"...  ...
# 1353  {"RowData":[{"CellData":"3.0","ColumnHeader":"...  ...
#
#                                               Education     Sex  \
# 0                           Some college, but no degree  Female
# 1           Bachelor's degree (for example: BA, AB, BS)    Male
# 2           Bachelor's degree (for example: BA, AB, BS)    Male
# 3                           Some college, but no degree    Male
# 4     Master's degree (for example: MA, MS, MEng, ME...  Female
# ...                                                 ...     ...
# 1349             Associate degree (for example: AA, AS)  Female
# 1350  Master's degree (for example: MA, MS, MEng, ME...  Female
# 1351                        Some college, but no degree  Female
# 1352        Bachelor's degree (for example: BA, AB, BS)  Female
# 1353  Master's degree (for example: MA, MS, MEng, ME...  Female
#
#                           Occupation Field Relationship/Marital Status  \
# 0     Business Management & Administration           In a relationship
# 1                                     Arts           In a relationship
# 2                   Information Technology                     Married
# 3                                    Other                    Divorced
# 4                     Education & Training                     Married
# ...                                    ...                         ...
# 1349                              Medicine                     Widowed
# 1350                                  Arts                      Single
# 1351                Information Technology                      Single
# 1352                                  Arts                     Married
# 1353                               Finance                     Married
#
#      Political Party Gender Country Of Residence   Household Income  \
# 0           Democrat  Woman        United States  Prefer not to say
# 1           Democrat    Man        United States    $60,000-$69,999
# 2           Democrat    Man        United States  $200,000-$224,999
# 3           Democrat    Man        United States    $30,000-$39,999
# 4        Independent  Woman        United States  $100,000-$124,999
# ...              ...    ...                  ...                ...
# 1349     Independent  Woman        United States    $50,000-$59,999
# 1350        Democrat  Woman        United States  Less than $10,000
# 1351        Democrat  Woman        United States    $30,000-$39,999
# 1352        Democrat  Woman        United States   $250,000 or more
# 1353        Democrat  Woman        United States  $200,000-$224,999
#
#                               Race Employment Status
# 0                Prefer not to say        Unemployed
# 1     An ethnicity not listed here         Full-time
# 2                            White         Full-time
# 3                            White         Full-time
# 4                            White         Full-time
# ...                            ...               ...
# 1349     Black or African American         Full-time
# 1350                         White        Unemployed
# 1351     Black or African American         Full-time
# 1352                         White         Full-time
# 1353                         White         Full-time
#
# [1354 rows x 22 columns]

# %%
exclude_participants_ids = first_survey["ParticipantId"].values

# %%
with open('exclude_participants.txt', 'w') as f:
    for line in exclude_participants_ids:
        f.write(f"{line}\n")
